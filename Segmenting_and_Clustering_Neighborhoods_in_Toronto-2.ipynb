# %% [markdown]
# ## Segmenting and Clustering Neighborhoods in Toronto #2

# %%
# importing the library and pulling the Wikipedia article
import requests
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %%
# importing the library for scraping the website content
from bs4 import BeautifulSoup
soup = BeautifulSoup(website_url,'lxml')
# checking the content
#print(soup.prettify())

# %% [markdown]
# We will be exploring the HTML tags and extracting the table data. First, we have to locate the right table.

# %%
# Using BeautifulSoup to obtain the data that is in the table of postal codes
My_table = soup.find('table',{'class':'wikitable sortable'})
#My_table

# %% [markdown]
# As we can see, the tags we need are "tr" and "td". Let's start extracting the table data. Each table column will be stored in the separate list.

# %%
A=[]
B=[]
C=[]

for row in My_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==3:
        A.append(cells[0].find(text=True)[:-1])
        B.append(cells[1].find(text=True)[:-1])
        C.append(cells[2].find(text=True)[:-1])
#C

# %% [markdown]
# Next, we will transform the data into a pandas dataframe with three columns.
# After that we'll do some data cleanup by removing the obsolete entries.

# %%
import pandas as pd
df = pd.DataFrame()
df['PostalCodes'] = A
df['Borough'] = B
df['Neighbourhood'] = C

df = df[~df['Borough'].isin(['Not assigned'])]
df.reset_index(drop = True, inplace = True)

df.head()
# Out:
#   PostalCodes           Borough                                Neighbourhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# Next, we'll check the dataframe columns and data:

# %%
print(df.columns)
df.head(20)
# Out:
# Index(['PostalCodes', 'Borough', 'Neighbourhood'], dtype='object')
#    PostalCodes           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
#
#                                         Neighbourhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                           Regent Park, Harbourfront
# 3                    Lawrence Manor, Lawrence Heights
# 4         Queen's Park, Ontario Provincial Government
# 5             Islington Avenue, Humber Valley Village
# 6                                      Malvern, Rouge
# 7                                           Don Mills
# 8                     Parkview Hill, Woodbine Gardens
# 9                            Garden District, Ryerson
# 10                                          Glencairn
# 11  West Deane Park, Princess Gardens, Martin Grov...
# 12             Rouge Hill, Port Union, Highland Creek
# 13                                          Don Mills
# 14                                   Woodbine Heights
# 15                                     St. James Town
# 16                                 Humewood-Cedarvale
# 17  Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 18                  Guildwood, Morningside, West Hill
# 19                                        The Beaches

# %% [markdown]
# Finally, let's check the dataframe dimensions.

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# Now that we have built a dataframe of the postal code of each neighborhood along with the borough name and neighborhood name, in order to utilize the Foursquare location data, we need to get the latitude and the longitude coordinates of each neighborhood. We will use the csv file because it is provided.

# %%
csv_path = "Downloads/Geospatial_Coordinates.csv"
dfGeo = pd.read_csv(csv_path)
# rename column to align between two dataframes
dfGeo.rename(columns = {'Postal Code':'PostalCodes'}, inplace = True) 
dfGeo.head()
# Out:
#   PostalCodes   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# We merge two frames on column "PostalCodes" in order to create a single table, then we sort it by postal code.

# %%
df = pd.merge(df, dfGeo, on="PostalCodes")
print(df.columns)
df.sort_index(axis = 1) 
df.head()
# Out:
# Index(['PostalCodes', 'Borough', 'Neighbourhood', 'Latitude', 'Longitude'], dtype='object')
#   PostalCodes           Borough                                Neighbourhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# Since the google geocoder didn't work well, trying another geocoder:

# %%
#!pip install geopy
#!pip install geocoder
#import geopy # 
#import geocoder
#from geopy.geocoders import Nominatim

#!pip install pgeocode
import pgeocode
nomi = pgeocode.Nominatim('ca')

geoA=[]
geoB=[]
geoC=[]

print("Start!")

# initialize the counter
i = 0

for postal_code in df['PostalCodes']:
    print("Processing postal code {} out of 103".format(i) + " -> {}".format(postal_code))
    location = nomi.query_postal_code(postal_code)
    geoA.append(postal_code)
    geoB.append(location.latitude)
    geoC.append(location.longitude)
    print(postal_code+", "+str(location.latitude)+", "+str(location.longitude))
    i = i + 1

print("Done!")
# Out:
# Start!
# Processing postal code 0 out of 103 -> M3A
# M3A, 43.7545, -79.33
# Processing postal code 1 out of 103 -> M4A
# M4A, 43.7276, -79.3148
# Processing postal code 2 out of 103 -> M5A
# M5A, 43.6555, -79.3626
# Processing postal code 3 out of 103 -> M6A
# M6A, 43.7223, -79.4504
# Processing postal code 4 out of 103 -> M7A
# M7A, 43.6641, -79.3889
# Processing postal code 5 out of 103 -> M9A
# M9A, 43.6662, -79.5282
# Processing postal code 6 out of 103 -> M1B
# M1B, 43.8113, -79.193
# Processing postal code 7 out of 103 -> M3B
# M3B, 43.745, -79.359
# Processing postal code 8 out of 103 -> M4B
# M4B, 43.7063, -79.3094
# Processing postal code 9 out of 103 -> M5B
# M5B, 43.6572, -79.3783
# Processing postal code 10 out of 103 -> M6B
# M6B, 43.7081, -79.4479
# Processing postal code 11 out of 103 -> M9B
# M9B, 43.6505, -79.5517
# Processing postal code 12 out of 103 -> M1C
# M1C, 43.7878, -79.1564
# Processing postal code 13 out of 103 -> M3C
# M3C, 43.7334, -79.3329
# Processing postal code 14 out of 103 -> M4C
# M4C, 43.6913, -79.3116
# Processing postal code 15 out of 103 -> M5C
# M5C, 43.6513, -79.3756
# Processing postal code 16 out of 103 -> M6C
# M6C, 43.6915, -79.4307
# Processing postal code 17 out of 103 -> M9C
# M9C, 43.6437, -79.5767
# Processing postal code 18 out of 103 -> M1E
# M1E, 43.7678, -79.1866
# Processing postal code 19 out of 103 -> M4E
# M4E, 43.6784, -79.2941
# Processing postal code 20 out of 103 -> M5E
# M5E, 43.6456, -79.3754
# Processing postal code 21 out of 103 -> M6E
# M6E, 43.6889, -79.4507
# Processing postal code 22 out of 103 -> M1G
# M1G, 43.7712, -79.2144
# Processing postal code 23 out of 103 -> M4G
# M4G, 43.7124, -79.3644
# Processing postal code 24 out of 103 -> M5G
# M5G, 43.6564, -79.38600000000002
# Processing postal code 25 out of 103 -> M6G
# M6G, 43.6683, -79.4205
# Processing postal code 26 out of 103 -> M1H
# M1H, 43.7686, -79.2389
# Processing postal code 27 out of 103 -> M2H
# M2H, 43.8015, -79.3577
# Processing postal code 28 out of 103 -> M3H
# M3H, 43.7535, -79.4472
# Processing postal code 29 out of 103 -> M4H
# M4H, 43.7059, -79.3464
# Processing postal code 30 out of 103 -> M5H
# M5H, 43.6496, -79.3833
# Processing postal code 31 out of 103 -> M6H
# M6H, 43.6655, -79.4378
# Processing postal code 32 out of 103 -> M1J
# M1J, 43.7464, -79.2323
# Processing postal code 33 out of 103 -> M2J
# M2J, 43.7801, -79.3479
# Processing postal code 34 out of 103 -> M3J
# M3J, 43.7694, -79.4921
# Processing postal code 35 out of 103 -> M4J
# M4J, 43.6872, -79.3368
# Processing postal code 36 out of 103 -> M5J
# M5J, 43.62300000000001, -79.3936
# Processing postal code 37 out of 103 -> M6J
# M6J, 43.648, -79.4177
# Processing postal code 38 out of 103 -> M1K
# M1K, 43.7298, -79.2639
# Processing postal code 39 out of 103 -> M2K
# M2K, 43.7797, -79.3813
# Processing postal code 40 out of 103 -> M3K
# M3K, 43.739, -79.4692
# Processing postal code 41 out of 103 -> M4K
# M4K, 43.6803, -79.3538
# Processing postal code 42 out of 103 -> M5K
# M5K, 43.6469, -79.3823
# Processing postal code 43 out of 103 -> M6K
# M6K, 43.6383, -79.4301
# Processing postal code 44 out of 103 -> M1L
# M1L, 43.7122, -79.2843
# Processing postal code 45 out of 103 -> M2L
# M2L, 43.7547, -79.3764
# Processing postal code 46 out of 103 -> M3L
# M3L, 43.7334, -79.5116
# Processing postal code 47 out of 103 -> M4L
# M4L, 43.6693, -79.3155
# Processing postal code 48 out of 103 -> M5L
# M5L, 43.6492, -79.3823
# Processing postal code 49 out of 103 -> M6L
# M6L, 43.7137, -79.4869
# Processing postal code 50 out of 103 -> M9L
# M9L, 43.7598, -79.5565
# Processing postal code 51 out of 103 -> M1M
# M1M, 43.7247, -79.2312
# Processing postal code 52 out of 103 -> M2M
# M2M, 43.7915, -79.4103
# Processing postal code 53 out of 103 -> M3M
# M3M, 43.7319, -79.4928
# Processing postal code 54 out of 103 -> M4M
# M4M, 43.6561, -79.3406
# Processing postal code 55 out of 103 -> M5M
# M5M, 43.7335, -79.4177
# Processing postal code 56 out of 103 -> M6M
# M6M, 43.6934, -79.4857
# Processing postal code 57 out of 103 -> M9M
# M9M, 43.7366, -79.5401
# Processing postal code 58 out of 103 -> M1N
# M1N, 43.6952, -79.2646
# Processing postal code 59 out of 103 -> M2N
# M2N, 43.7673, -79.4111
# Processing postal code 60 out of 103 -> M3N
# M3N, 43.7568, -79.521
# Processing postal code 61 out of 103 -> M4N
# M4N, 43.7301, -79.3935
# Processing postal code 62 out of 103 -> M5N
# M5N, 43.7113, -79.4195
# Processing postal code 63 out of 103 -> M6N
# M6N, 43.6748, -79.4839
# Processing postal code 64 out of 103 -> M9N
# M9N, 43.7068, -79.517
# Processing postal code 65 out of 103 -> M1P
# M1P, 43.7612, -79.2707
# Processing postal code 66 out of 103 -> M2P
# M2P, 43.75, -79.3978
# Processing postal code 67 out of 103 -> M4P
# M4P, 43.7135, -79.3887
# Processing postal code 68 out of 103 -> M5P
# M5P, 43.6966, -79.41199999999998
# Processing postal code 69 out of 103 -> M6P
# M6P, 43.6605, -79.4633
# Processing postal code 70 out of 103 -> M9P
# M9P, 43.6949, -79.5323
# Processing postal code 71 out of 103 -> M1R
# M1R, 43.7507, -79.3003
# Processing postal code 72 out of 103 -> M2R
# M2R, 43.7786, -79.445
# Processing postal code 73 out of 103 -> M4R
# M4R, 43.7143, -79.4065
# Processing postal code 74 out of 103 -> M5R
# M5R, 43.6736, -79.4035
# Processing postal code 75 out of 103 -> M6R
# M6R, 43.6469, -79.4521
# Processing postal code 76 out of 103 -> M7R
# M7R, nan, nan
# Processing postal code 77 out of 103 -> M9R
# M9R, 43.6898, -79.5582
# Processing postal code 78 out of 103 -> M1S
# M1S, 43.7946, -79.2644
# Processing postal code 79 out of 103 -> M4S
# M4S, 43.702, -79.3853
# Processing postal code 80 out of 103 -> M5S
# M5S, 43.6629, -79.3987
# Processing postal code 81 out of 103 -> M6S
# M6S, 43.6512, -79.4828
# Processing postal code 82 out of 103 -> M1T
# M1T, 43.7812, -79.3036
# Processing postal code 83 out of 103 -> M4T
# M4T, 43.6899, -79.3853
# Processing postal code 84 out of 103 -> M5T
# M5T, 43.6541, -79.3978
# Processing postal code 85 out of 103 -> M1V
# M1V, 43.8177, -79.2819
# Processing postal code 86 out of 103 -> M4V
# M4V, 43.6861, -79.4025
# Processing postal code 87 out of 103 -> M5V
# M5V, 43.6404, -79.3995
# Processing postal code 88 out of 103 -> M8V
# M8V, 43.6075, -79.5013
# Processing postal code 89 out of 103 -> M9V
# M9V, 43.7432, -79.5876
# Processing postal code 90 out of 103 -> M1W
# M1W, 43.8016, -79.3216
# Processing postal code 91 out of 103 -> M4W
# M4W, 43.6827, -79.373
# Processing postal code 92 out of 103 -> M5W
# M5W, 43.6437, -79.3787
# Processing postal code 93 out of 103 -> M8W
# M8W, 43.6021, -79.5402
# Processing postal code 94 out of 103 -> M9W
# M9W, 43.7144, -79.5909
# Processing postal code 95 out of 103 -> M1X
# M1X, 43.834, -79.2069
# Processing postal code 96 out of 103 -> M4X
# M4X, 43.6684, -79.3689
# Processing postal code 97 out of 103 -> M5X
# M5X, 43.6492, -79.3823
# Processing postal code 98 out of 103 -> M8X
# M8X, 43.6518, -79.5076
# Processing postal code 99 out of 103 -> M4Y
# M4Y, 43.6656, -79.383
# Processing postal code 100 out of 103 -> M7Y
# M7Y, 43.7804, -79.2505
# Processing postal code 101 out of 103 -> M8Y
# M8Y, 43.6325, -79.4939
# Processing postal code 102 out of 103 -> M8Z
# M8Z, 43.6256, -79.5231
# Done!

# %% [markdown]
# Merging the lists into the dataframe

# %%
import pandas as pd
dfGeoAlt = pd.DataFrame()

dfGeoAlt['PostalCodes'] = geoA
dfGeoAlt['Latitude'] = geoB
dfGeoAlt['Longitude'] = geoC
dfGeoAlt.head()
# Out:
#   PostalCodes  Latitude  Longitude
# 0         M3A   43.7545   -79.3300
# 1         M4A   43.7276   -79.3148
# 2         M5A   43.6555   -79.3626
# 3         M6A   43.7223   -79.4504
# 4         M7A   43.6641   -79.3889

# %%
dfGeoAlt.shape
# Out:
# (103, 3)

# %% [markdown]
# Therefore, we were able to use both csv file and geocoder package to get the geographical coordinates of the neighborhoods and create the dataframes. This concludes notebook 2.
